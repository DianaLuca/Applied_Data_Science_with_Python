# %% [markdown]
# # Assignment 2
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# An NOAA dataset has been stored in the file `data/C2A2_data/BinnedCsvs_d400/fb441e62df2d58994928907a91895ec62c2c42e6cd075c2700843b89.csv`. The data for this assignment comes from a subset of The National Centers for Environmental Information (NCEI) [Daily Global Historical Climatology Network](https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/readme.txt) (GHCN-Daily). The GHCN-Daily is comprised of daily climate records from thousands of land surface stations across the globe.
#
# Each row in the assignment datafile corresponds to a single observation.
#
# The following variables are provided to you:
#
# * **id** : station identification code
# * **date** : date in YYYY-MM-DD format (e.g. 2012-01-24 = January 24, 2012)
# * **element** : indicator of element type
#     * TMAX : Maximum temperature (tenths of degrees C)
#     * TMIN : Minimum temperature (tenths of degrees C)
# * **value** : data value for element (tenths of degrees C)
#
# For this assignment, you must:
#
# 1. Read the documentation and familiarize yourself with the dataset, then write some python code which returns a line graph of the record high and record low temperatures by day of the year over the period 2005-2014. The area between the record high and record low temperatures for each day should be shaded.
# 2. Overlay a scatter of the 2015 data for any points (highs and lows) for which the ten year record (2005-2014) record high or record low was broken in 2015.
# 3. Watch out for leap days (i.e. February 29th), it is reasonable to remove these points from the dataset for the purpose of this visualization.
# 4. Make the visual nice! Leverage principles from the first module in this course when developing your solution. Consider issues such as legends, labels, and chart junk.
#
# The data you have been given is near **Ann Arbor, Michigan, United States**, and the stations the data comes from are shown on the map below.

# %%
import matplotlib.pyplot as plt
import mplleaflet  #pip3 install mplleaflet
import pandas as pd

def leaflet_plot_stations(binsize, hashid):

    df = pd.read_csv('BinSize_d{}.csv'.format(binsize))

    station_locations_by_hash = df[df['hash'] == hashid]

    lons = station_locations_by_hash['LONGITUDE'].tolist()
    lats = station_locations_by_hash['LATITUDE'].tolist()

    plt.figure(figsize=(8,8))

    plt.scatter(lons, lats, c='r', alpha=0.8, s=200)

    return mplleaflet.display()

#leaflet_plot_stations(13, '31428e6fe40a3964bffbc18d60e8775fd4920c8a4489aeb2aa548b10')
leaflet_plot_stations(400,'fb441e62df2d58994928907a91895ec62c2c42e6cd075c2700843b89')
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="480"></iframe>

# %% [markdown]
# ### Ann Arbor, Michigan, United States min_max_temperature_line_graph

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

# %% [markdown]
# Each row in the assignment datafile corresponds to a single observation.
#
# The following variables are provided to you:
#
# * id : station identification code
# * date : date in YYYY-MM-DD format (e.g. 2012-01-24 = January 24, 2012)
# * element : indicator of element type
#     * TMAX : Maximum temperature (tenths of degrees C)
#     * TMIN : Minimum temperature (tenths of degrees C)
# * value : data value for element (tenths of degrees C) (When it says Celsius degrees to tenths you have to divide it by 10 and you will get the actual temperature.)

# %%
df = pd.read_csv('fb441e62df2d58994928907a91895ec62c2c42e6cd075c2700843b89.csv')
df = df.sort_values(by='Date')
df.Date = pd.to_datetime(df['Date'], format='%Y-%m-%d')
df = df.set_index("Date").drop("ID",axis=1)
df_set05_14 = df.loc['2005-01-01':'2014-12-31']
df_set_15 = df.loc['2015-01-01':]

# %%
def process_df(df, element):
    df = df.reset_index()
    df['Date'] = df['Date'].apply(lambda el: el[5:])
    df = df.loc[df.Date != '02-29']
    df = df.set_index(['Date'])
    df = df[df.Element == element]
    df = df.drop(['Element'], axis=1)
    return df.groupby(df.index).max() / 10.0 if element == 'TMAX' else df.groupby(df.index).min() / 10.0

df_by_dm_05_14_min = process_df(df_set05_14,  'TMIN')
df_by_dm_05_14_max = process_df(copy_df_set05_14,  'TMAX')
df_by_dm_15_min = process_df(df_set_15, 'TMIN')
df_by_dm_15_max = process_df(copy_df_set_15, 'TMAX')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-acc6f3863516> in <module>()
#       8     return df.groupby(df.index).max() / 10.0 if element == 'TMAX' else df.groupby(df.index).min() / 10.0
#       9
# ---> 10 df_by_dm_05_14_min = process_df(df_set05_14,  'TMIN')
#      11 df_by_dm_05_14_max = process_df(copy_df_set05_14,  'TMAX')
#      12 df_by_dm_15_min = process_df(df_set_15, 'TMIN')
#
# <ipython-input-43-acc6f3863516> in process_df(df, element)
#       1 def process_df(df, element):
#       2     df = df.reset_index()
# ----> 3     df['Date'] = df['Date'].apply(lambda el: el[5:])
#       4     df = df.loc[df.Date != '02-29']
#       5     df = df.set_index(['Date'])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2292             else:
# ...

# %%
df_by_dm_05_14_min.head(5)
# Out:
#        Data_Value
# Date
# 01-01       -16.0
# 01-02       -26.7
# 01-03       -26.7
# 01-04       -26.1
# 01-05       -15.0

# %%
#df_by_dm_05_14_min.index = lambda float(x) : x in df_by_dm_05_14_min.index.values

df_by_dm_05_14_min.index = list(map(lambda x: float(x.replace(",", "-")), df_by_dm_05_14_min.index.values))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-bbe1c3f9e6d8> in <module>()
#       1 #df_by_dm_05_14_min.index = lambda float(x) : x in df_by_dm_05_14_min.index.values
#       2
# ----> 3 df_by_dm_05_14_min.index = list(map(lambda x: float(x.replace(",", "-")), df_by_dm_05_14_min.index.values))
#       4
#       5
#
# <ipython-input-33-bbe1c3f9e6d8> in <lambda>(x)
#       1 #df_by_dm_05_14_min.index = lambda float(x) : x in df_by_dm_05_14_min.index.values
#       2
# ----> 3 df_by_dm_05_14_min.index = list(map(lambda x: float(x.replace(",", "-")), df_by_dm_05_14_min.index.values))
#       4
#       5
#
# ValueError: could not convert string to float: '01-01'

# %%
plt.figure(figsize=(13,7))
plt.plot(df_by_dm_05_14_min)
plt.plot(df_by_dm_05_14_max)

ax = plt.gca()

months = ['Jan 1st','Feb 1st','Mar 1st','Apr 1st','May 1st','Jun 1st','Jul 1st','Aug 1st','Sep 1st','Oct 1st','Nov 1st','Dec 1st']
ax.set_xticklabels(months + ['End of year'])
xticks = ['{:02}-01'.format(i) for i in range(1, 13)] + ['12-31']
ax.set_xticks(xticks)

# Set the x scale
ax.set_xlim((-5, 370))
ax.set_ylim((-35, 45))

# Set the x-axis and y-axis labels
ax.set_xlabel('Days of the year', fontsize=13)
ax.set_ylabel('Temperature °C', fontsize=13)

# add a title
plt.title("2015 temperature records compared to 2005-2014 for the past 10 years",  fontsize=13)
plt.suptitle('Weather Patterns in Ann Arbor, Michigan, United States', alpha=0.8, fontsize=15)

for spine in ax.spines.values():
    spine.set_visible(False)

for item in ax.xaxis.get_ticklabels():
    item.set_rotation(45)

# Fill in between the high and low measurements
date_index = np.array(df_by_dm_15.index.tolist())
#print(type(date_index), date_index)
ax.fill_between(df_by_dm_05_14_min.index, df_by_dm_05_14_min.Data_Value, df_by_dm_05_14_max.Data_Value, facecolor='pink', alpha=0.2)

breaking_high = df_by_dm_15_max[df_by_dm_15_max.Data_Value > df_by_dm_05_14_max.Data_Value]
breaking_low = df_by_dm_15_min[df_by_dm_15_min.Data_Value < df_by_dm_05_14_min.Data_Value]

plt.scatter(breaking_high.index.values, breaking_high.Data_Value.values, color='r')
plt.scatter(breaking_low.index.values, breaking_low.Data_Value.values, color='darkblue')

# add the legend to loc=4 (the lower right hand corner), also gets rid of the frame and adds a title
ax.legend(['Record lows 2004 - 2015', 'Record highs 2004 - 2015', 'Temperatures between the record high and record low', 'Record high in 2015 that broke 2004 - 2015',
           'Record low in 2015 that broke 2004 - 2015'], loc=8, title='Legend', fontsize=10)
#"2015 record Highs", "2015 record Lows"], loc='center left', bbox_to_anchor=(1.0, 0.5), prop={'size':12})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-7cac23546238> in <module>()
#       1 plt.figure(figsize=(13,7))
# ----> 2 plt.plot(df_by_dm_05_14_min)
#       3 plt.plot(df_by_dm_05_14_max)
#       4
#       5 ax = plt.gca()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3316                       mplDeprecation)
#    3317     try:
# -> 3318         ret = ax.plot(*args, **kwargs)
#    3319     finally:
#    3320         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
# ...

# %%
# !pip3 install --upgrade pandas==0.19.2

# %%
# !pip3 install --upgrade matplotlib==2.0.0

# %% [markdown]
# ### REDO for older pandas and matplotlib versions

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

# %%
df = pd.read_csv('fb441e62df2d58994928907a91895ec62c2c42e6cd075c2700843b89.csv')

df = df.drop("ID",axis=1).sort_values(by='Date')
df.Data_Value = df.Data_Value / 10 #transform from tenths of degrees C to C

# Convert Date column to date data type
df.Date = pd.to_datetime(df['Date'], format='%Y-%m-%d')


df = df.set_index("Date")

df
# Out:
#            Element  Data_Value
# Date
# 2005-01-01    TMIN         0.0
# 2005-01-01    TMAX        15.0
# 2005-01-01    TMIN        -1.1
# 2005-01-01    TMIN        -4.4
# 2005-01-01    TMAX         3.3
# 2005-01-01    TMIN        -5.0
# 2005-01-01    TMAX        13.3
# 2005-01-01    TMAX         2.8
# 2005-01-01    TMAX         5.6
# 2005-01-01    TMIN        -5.6
# 2005-01-01    TMIN        -3.9
# 2005-01-01    TMIN        -1.7
# 2005-01-01    TMAX         5.6
# 2005-01-01    TMAX        12.8
# 2005-01-01    TMIN        -4.4
# 2005-01-01    TMAX         4.4
# 2005-01-01    TMAX        12.8
# 2005-01-01    TMIN        -5.0
# 2005-01-01    TMAX        15.0
# 2005-01-01    TMAX        15.6
# 2005-01-01    TMAX        14.4
# 2005-01-01    TMIN        -3.3
# 2005-01-01    TMIN        -3.9
# 2005-01-01    TMIN        -3.9
# 2005-01-01    TMIN        -2.8
# 2005-01-01    TMIN        -3.9
# 2005-01-01    TMAX        15.0
# 2005-01-01    TMAX        15.0
# 2005-01-01    TMIN        -3.9
# ...
