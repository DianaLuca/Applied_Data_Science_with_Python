# %% [markdown]
# ### Merging Dataframes

# %%
import pandas as pd

# %%
products_df = pd.DataFrame([{'Product ID': 4109, 'Price':5.0, 'Product':'Sushi Roll'}, 
                {'Product ID': 1412, 'Price':0.5, 'Product':'Egg'}, 
                {'Product ID': 8931, 'Price':1.5, 'Product':'Bagel'}]).set_index('Product ID')
# products_df = products_df.set_index('Product ID')
products_df
# Out:
#             Price     Product
# Product ID
# 4109          5.0  Sushi Roll
# 1412          0.5         Egg
# 8931          1.5       Bagel

# %%
#products_df.set_index('Product ID')

# %%
invoices_df = pd.DataFrame([{'Customer':'Ali', 'Product ID': 4109, 'Quantity': 1}, 
                            {'Customer':'Eric', 'Product ID': 1412, 'Quantity': 12}, 
                            {'Customer':'Ande', 'Product ID': 8931, 'Quantity': 6},
                            {'Customer':'Sam', 'Product ID': 4109, 'Quantity': 2}])
invoices_df
# Out:
#   Customer  Product ID  Quantity
# 0      Ali        4109         1
# 1     Eric        1412        12
# 2     Ande        8931         6
# 3      Sam        4109         2

# %%
pd.merge(products_df, invoices_df, how='outer', left_index=True, right_index=True)
# Out:
#       Price     Product Customer  Product ID  Quantity
# 0       NaN         NaN      Ali      4109.0       1.0
# 1       NaN         NaN     Eric      1412.0      12.0
# 2       NaN         NaN     Ande      8931.0       6.0
# 3       NaN         NaN      Sam      4109.0       2.0
# 1412    0.5         Egg      NaN         NaN       NaN
# 4109    5.0  Sushi Roll      NaN         NaN       NaN
# 8931    1.5       Bagel      NaN         NaN       NaN

# %%
pd.merge(products_df, invoices_df, how='outer', left_index=True, right_index=True)
# Out:
#       Price     Product Customer  Product ID  Quantity
# 0       NaN         NaN      Ali      4109.0       1.0
# 1       NaN         NaN     Eric      1412.0      12.0
# 2       NaN         NaN     Ande      8931.0       6.0
# 3       NaN         NaN      Sam      4109.0       2.0
# 1412    0.5         Egg      NaN         NaN       NaN
# 4109    5.0  Sushi Roll      NaN         NaN       NaN
# 8931    1.5       Bagel      NaN         NaN       NaN

# %%
pd.merge(products_df, invoices_df, how='inner', left_index=True, right_index=True)
# Out:
# Empty DataFrame
# Columns: [Price, Product, Customer, Product ID, Quantity]
# Index: []

# %%
pd.merge(products_df, invoices_df, how='left', left_index=True, right_index=True)
# Out:
#             Price     Product Customer  Product ID  Quantity
# Product ID
# 4109          5.0  Sushi Roll      NaN         NaN       NaN
# 1412          0.5         Egg      NaN         NaN       NaN
# 8931          1.5       Bagel      NaN         NaN       NaN

# %%
pd.merge(products_df, invoices_df, how='right', left_index=True, right_index=True)
# Out:
#    Price Product Customer  Product ID  Quantity
# 0    NaN     NaN      Ali        4109         1
# 1    NaN     NaN     Eric        1412        12
# 2    NaN     NaN     Ande        8931         6
# 3    NaN     NaN      Sam        4109         2

# %%
products_df
# Out:
#             Price     Product
# Product ID
# 4109          5.0  Sushi Roll
# 1412          0.5         Egg
# 8931          1.5       Bagel

# %%
products_df = products_df.reset_index()
products_df
# Out:
#    Product ID  Price     Product
# 0        4109    5.0  Sushi Roll
# 1        1412    0.5         Egg
# 2        8931    1.5       Bagel

# %%
invoices_df
# Out:
#   Customer  Product ID  Quantity
# 0      Ali        4109         1
# 1     Eric        1412        12
# 2     Ande        8931         6
# 3      Sam        4109         2

# %%
invoices_df = invoices_df.reset_index()
invoices_df
# Out:
#    index Customer  Product ID  Quantity
# 0      0      Ali        4109         1
# 1      1     Eric        1412        12
# 2      2     Ande        8931         6
# 3      3      Sam        4109         2

# %%
pd.merge(products_df, invoices_df, how='left', left_on='Product ID', right_on='Product ID')
# Out:
#    Product ID  Price     Product  index Customer  Quantity
# 0        4109    5.0  Sushi Roll      0      Ali         1
# 1        4109    5.0  Sushi Roll      3      Sam         2
# 2        1412    0.5         Egg      1     Eric        12
# 3        8931    1.5       Bagel      2     Ande         6

# %% [markdown]
# ### Idiomatic Pandas: Pandorable code

# %%
import pandas as pd
df = pd.read_csv('census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
df.set_index(['STNAME','CTYNAME'])
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Alabama                 40       3         6      1       0
#           Autauga County          50       3         6      1       1
#           Baldwin County          50       3         6      1       3
#           Barbour County          50       3         6      1       5
#           Bibb County             50       3         6      1       7
#           Blount County           50       3         6      1       9
#           Bullock County          50       3         6      1      11
#           Butler County           50       3         6      1      13
#           Calhoun County          50       3         6      1      15
#           Chambers County         50       3         6      1      17
#           Cherokee County         50       3         6      1      19
#           Chilton County          50       3         6      1      21
# ...

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
(df.where(df['SUMLEV']==50)
    .dropna()
    .set_index(['STNAME','CTYNAME'])
    .rename(columns={'ESTIMATESBASE2010': 'Estimates Base 2010'}))
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County        50.0     3.0       6.0    1.0     1.0
#           Baldwin County        50.0     3.0       6.0    1.0     3.0
#           Barbour County        50.0     3.0       6.0    1.0     5.0
#           Bibb County           50.0     3.0       6.0    1.0     7.0
#           Blount County         50.0     3.0       6.0    1.0     9.0
#           Bullock County        50.0     3.0       6.0    1.0    11.0
#           Butler County         50.0     3.0       6.0    1.0    13.0
#           Calhoun County        50.0     3.0       6.0    1.0    15.0
#           Chambers County       50.0     3.0       6.0    1.0    17.0
#           Cherokee County       50.0     3.0       6.0    1.0    19.0
#           Chilton County        50.0     3.0       6.0    1.0    21.0
#           Choctaw County        50.0     3.0       6.0    1.0    23.0
# ...

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
df = df[df['SUMLEV'] == 50]
df.set_index(['STNAME', 'CTYNAME'], inplace=True)
df.rename(columns={'ESTIMATESBASE2010': 'Estimates Base 2010'})
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County          50       3         6      1       1
#           Baldwin County          50       3         6      1       3
#           Barbour County          50       3         6      1       5
#           Bibb County             50       3         6      1       7
#           Blount County           50       3         6      1       9
#           Bullock County          50       3         6      1      11
#           Butler County           50       3         6      1      13
#           Calhoun County          50       3         6      1      15
#           Chambers County         50       3         6      1      17
#           Cherokee County         50       3         6      1      19
#           Chilton County          50       3         6      1      21
#           Choctaw County          50       3         6      1      23
# ...

# %% [markdown]
# ### Min_Max

# %%
import numpy as np 
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    return pd.Series({'min': np.min(data), 'max': np.max(data)})

# %%
np.min(df[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']])
# Out:
# POPESTIMATE2010    83
# POPESTIMATE2011    90
# POPESTIMATE2012    81
# POPESTIMATE2013    89
# POPESTIMATE2014    87
# POPESTIMATE2015    89
# dtype: int64

# %%
np.max(df[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']])
# Out:
# POPESTIMATE2010     9826009
# POPESTIMATE2011     9896602
# POPESTIMATE2012     9970436
# POPESTIMATE2013    10045175
# POPESTIMATE2014    10109436
# POPESTIMATE2015    10170292
# dtype: int64

# %% [markdown]
# DataFrame.apply(func, axis)
#
# func : function
# Function to apply to each column or row.
#
# axis : {0 or ‘index’, 1 or ‘columns’}, default 0
# Axis along which the function is applied:
# 0 or ‘index’: apply function to each column.
# 1 or ‘columns’: apply function to each row.

# %%
df.apply(min_max, axis=1)
# Out:
#                                    max       min
# STNAME    CTYNAME
# Alabama   Autauga County       55347.0   54660.0
#           Baldwin County      203709.0  183193.0
#           Barbour County       27341.0   26489.0
#           Bibb County          22861.0   22512.0
#           Blount County        57776.0   57373.0
#           Bullock County       10887.0   10606.0
#           Butler County        20944.0   20154.0
#           Calhoun County      118437.0  115620.0
#           Chambers County      34153.0   33993.0
#           Cherokee County      26084.0   25859.0
#           Chilton County       43943.0   43665.0
#           Choctaw County       13841.0   13170.0
#           Clarke County        25767.0   24675.0
#           Clay County          13880.0   13456.0
#           Cleburne County      15072.0   14921.0
#           Coffee County        51211.0   50177.0
#           Colbert County       54514.0   54354.0
#           Conecuh County       13208.0   12662.0
# ...

# %%
import numpy as np
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    row['max'] = np.max(data)
    row['min'] = np.min(data)
    return row

df.apply(min_max, axis=1)
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 0         40       3         6      1       0    Alabama             Alabama
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# ...

# %%
# Suppose we are working on a DataFrame that holds information on our equipment for an upcoming backpacking trip.

#Can you use method chaining to modify the DataFrame df in one statement 
#to drop any entries where 'Quantity' is 0 and 
#rename the column 'Weight' to 'Weight (oz.)'?
# 


df = (df.where(df[ 'Quantity']!=0)
  .dropna()
  .rename(columns={'Weight':'Weight (oz.)'}))
print(df)


Item                                                   
Pack                       Pack       1.0          33.0
Tent                    Shelter       1.0          80.0
Sleeping Bag              Sleep       1.0          20.0
Toothbrush/Toothpaste    Health       1.0           2.0
Sunscreen                Health       1.0           5.0
Medical Kit              Health       1.0           3.7
Stove                   Kitchen       1.0          20.0
Water Filter            Kitchen       1.0           1.8
Water Bottles           Kitchen       2.0          35.0
Pack Liner              Utility       1.0           1.0
Trekking Poles          Utility       1.0          16.0
Shoes                  Clothing       1.0          12.0
Hat                    Clothing       1.0           2.5

# Alternative solution_2:
#  print(df.drop(df[df['Quantity'] == 0].index)
#      .rename(columns={'Weight': 'Weight (oz.)'}))
# drop(df[df['Quantity'] == 0].index) instead of df.where(df[..]..).dropna()

# %% [markdown]
# ## Group by

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('census.csv')
df = df[df['SUMLEV']==50]
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
# 5          57322              57322            57373     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 1          7.242091         -2.915927         -3.012349          2.265971
# ...

# %%
# %%timeit -n 10  # "%%timeit" is a built-in magic command, 
                # "%%" executed in cell mode, "%" usage in line mode

for state in df['STNAME'].unique():
    avg = np.average(df[df['STNAME']==state].dropna()['CENSUS2010POP'])
    print('Counties in state ' + state + ' have an average population of ' + str(avg))
# Out:
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# ...

# %%
for group, frame in df.groupby('STNAME'):
    print(group)
    print(frame.head(5))
# Out:
# Alabama
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
# 5          57322              57322            57373     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 1          7.242091         -2.915927         -3.012349          2.265971
# ...

# %%
# %%timeit -n 10
for group, frame in df.groupby('STNAME'):
    avg = np.average(frame['CENSUS2010POP'])
    print('Counties in state ' + group + ' have an average population of ' + str(avg))
# Out:
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# ...

# %%
df.head(3)
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 1          7.242091         -2.915927         -3.012349          2.265971
# 2         14.832960         17.647293         21.845705         19.243287
# 3         -4.728132         -2.500690         -7.056824         -3.904217
#
#    RDOMESTICMIG2015  RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  \
# ...

# %%
df = pd.read_csv('census.csv')
df = df[df['SUMLEV']==50]


df = df.set_index('STNAME')

def fun(item):
    if item[0]<'M':
        return 0
    if item[0]<'Q':
        return 1
    return 2

for group, frame in df.groupby(fun):
    print('There are ' + str(len(frame)) + ' records in group ' + str(group) + ' for processing.')
# Out:
# There are 1177 records in group 0 for processing.
# There are 1134 records in group 1 for processing.
# There are 831 records in group 2 for processing.

# %%
df.groupby('STNAME').groups
# Out:
# {'Alabama': Index(['Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama',
#         'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama',
#         'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama',
#         'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama',
#         'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama',
#         'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama',
#         'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama',
#         'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama',
#         'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama',
#         'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama',
#         'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama',
#         'Alabama'],
#        dtype='object', name='STNAME'),
#  'Alaska': Index(['Alaska', 'Alaska', 'Alaska', 'Alaska', 'Alaska', 'Alaska', 'Alaska',
# ...

# %%
df = pd.read_csv('census.csv')
df = df[df['SUMLEV']==50]

# %%
df.groupby('STNAME').agg({'CENSUS2010POP': np.average})
# Out:
#                       CENSUS2010POP
# STNAME
# Alabama                71339.343284
# Alaska                 24490.724138
# Arizona               426134.466667
# Arkansas               38878.906667
# California            642309.586207
# Colorado               78581.187500
# Connecticut           446762.125000
# Delaware              299311.333333
# District of Columbia  601723.000000
# Florida               280616.567164
# Georgia                60928.635220
# Hawaii                272060.200000
# Idaho                  35626.863636
# Illinois              125790.509804
# Indiana                70476.108696
# Iowa                   30771.262626
# Kansas                 27172.552381
# Kentucky               36161.391667
# Louisiana              70833.937500
# Maine                  83022.562500
# Maryland              240564.666667
# Massachusetts         467687.785714
# Michigan              119080.000000
# Minnesota              60964.655172
# Mississippi            36186.548780
# ...

# %%
print(type(df.groupby(level=0)['POPESTIMATE2010', 'POPESTIMATE2011']))
# Out:
# <class 'pandas.core.groupby.DataFrameGroupBy'>

# %%
print(type(df.groupby(level=0)['POPESTIMATE2010']))
# Out:
# <class 'pandas.core.groupby.SeriesGroupBy'>

# %%
df.groupby(level=0)['POPESTIMATE2010', 'POPESTIMATE2011'].head()
# Out:
#       POPESTIMATE2010  POPESTIMATE2011
# 1               54660            55253
# 2              183193           186659
# 3               27341            27226
# 4               22861            22733
# 5               57373            57711
# 6               10887            10629
# 7               20944            20673
# 8              118437           117768
# 9               34098            33993
# 10              25976            26080
# 11              43665            43739
# 12              13841            13593
# 13              25767            25570
# 14              13880            13670
# 15              14973            14971
# 16              50177            50448
# 17              54514            54443
# 18              13208            13121
# 19              11758            11348
# 20              37796            38060
# 21              13853            13896
# 22              80473            80469
# 23              50358            50109
# ...
